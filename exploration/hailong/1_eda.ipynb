# %%
# %load_ext lab_black

# %%
import pandas as pd 
import numpy as np

pd.set_option('display.max_columns', 100)

# %%
credits = pd.read_csv("data/credits.csv")

# %%
credits.head()
# Out:
#                                                 cast  \
# 0  [{'cast_id': 14, 'character': 'Woody (voice)',...
# 1  [{'cast_id': 1, 'character': 'Alan Parrish', '...
# 2  [{'cast_id': 2, 'character': 'Max Goldman', 'c...
# 3  [{'cast_id': 1, 'character': "Savannah 'Vannah...
# 4  [{'cast_id': 1, 'character': 'George Banks', '...
#
#                                                 crew     id
# 0  [{'credit_id': '52fe4284c3a36847f8024f49', 'de...    862
# 1  [{'credit_id': '52fe44bfc3a36847f80a7cd1', 'de...   8844
# 2  [{'credit_id': '52fe466a9251416c75077a89', 'de...  15602
# 3  [{'credit_id': '52fe44779251416c91011acb', 'de...  31357
# 4  [{'credit_id': '52fe44959251416c75039ed7', 'de...  11862

# %% [markdown]
# ### preprocess

# %%
credits.cast = credits.cast.apply(ast.literal_eval)
credits.crew = credits.crew.apply(ast.literal_eval)

# %%
cdf = credits[['id']]

# %%
cdf['cast_list'] = credits.cast.apply(lambda x: [y['name'] for y in x])
cdf['crew_list'] = credits.crew.apply(lambda x: [y['name'] for y in x])
# Out:
# C:\Users\hailo\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
cdf.cast_list.explode().value_counts()
# Out:
# Bess Flowers         241
# Christopher Lee      148
# John Wayne           125
# Samuel L. Jackson    123
# Michael Caine        110
#                     ...
# Jeffrey Noel           1
# Mariangela Pagan       1
# Derek Anthony          1
# Shannon Vann           1
# Kyle Hansen            1
# Name: cast_list, Length: 202747, dtype: int64

# %%
cdf.crew_list.explode().value_counts()
# Out:
# Cedric Gibbons     272
# Avy Kaufman        184
# Edith Head         165
# Roger Corman       155
# Ennio Morricone    153
#                   ...
# Yuri Perov           1
# Carolina Groppa      1
# Shi Jianxiang        1
# Jana Lynn Gold       1
# Manu Chao            1
# Name: crew_list, Length: 157614, dtype: int64

# %%
cdf
# Out:
#            id                                          cast_list  \
# 0         862  [Tom Hanks, Tim Allen, Don Rickles, Jim Varney...
# 1        8844  [Robin Williams, Jonathan Hyde, Kirsten Dunst,...
# 2       15602  [Walter Matthau, Jack Lemmon, Ann-Margret, Sop...
# 3       31357  [Whitney Houston, Angela Bassett, Loretta Devi...
# 4       11862  [Steve Martin, Diane Keaton, Martin Short, Kim...
# ...       ...                                                ...
# 45471  439050        [Leila Hatami, Kourosh Tahami, Elham Korda]
# 45472  111109  [Angel Aquino, Perry Dizon, Hazel Orencio, Joe...
# 45473   67758  [Erika Eleniak, Adam Baldwin, Julie du Page, J...
# 45474  227506  [Iwan Mosschuchin, Nathalie Lissenko, Pavel Pa...
# 45475  461257                                                 []
#
#                                                crew_list
# 0      [John Lasseter, Joss Whedon, Andrew Stanton, J...
# 1      [Larry J. Franco, Jonathan Hensleigh, James Ho...
# ...

# %%
cast_movies = cdf.explode(column="cast_list").groupby(by="cast_list").id.apply(list)
crew_movies = cdf.explode(column = "crew_list").groupby(by = "crew_list").id.apply(list)

# %%
cast_movies.reset_index()
# Out:
#                     cast_list  \
# 0           \tCheung Chi-Sing
# 1           \tDouglas Hegdahl
# 2               \tRobert Osth
# 3                  \tYip Chun
# 4         Jorge de los Reyes
# ...                       ...
# 202742                   长泽雅美
# 202743                    陳美貞
# 202744                   高桥一生
# 202745                    강계열
# 202746                    조병만
#
#                                                        id
# 0                                                 [17082]
# 1                                                 [56235]
# 2                                                 [39867]
# 3                                          [32151, 41387]
# 4                                                [242575]
# ...                                                   ...
# 202742  [36091, 20722, 79382, 83389, 208700, 39469, 31...
# 202743                                           [265712]
# 202744  [24, 393, 15080, 37797, 36091, 22025, 40701, 2...
# ...

# %%
crew_movies.reset_index()
# Out:
#                 crew_list                        id
# 0       \tCheung Chi-Sing            [18857, 10703]
# 1             \tJiang Jun                  [315669]
# 2           \tMak Tin-Shu           [34179, 290864]
# 3        \tPertti Pasanen                   [36767]
# 4                \tSo Lam                   [21537]
# ...                   ...                       ...
# 157609                진모영  [306598, 306598, 306598]
# 157610                최광식                   [83754]
# 157611                최세연                   [81460]
# 157612                한소현                   [81460]
# 157613                허종호                   [82477]
#
# [157614 rows x 2 columns]
